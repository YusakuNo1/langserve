# %% [markdown]
# # Client
#
# Demo of a client interacting with a remote agent.

# %% [markdown]
# You can interact with this via API directly

# %%
import requests

inputs = {"input": {"input": "what does eugene think of cats?"}}
response = requests.post("http://localhost:8000/invoke", json=inputs)

response.json()
# Out:
# {'output': {'output': 'Eugene thinks that cats like fish.'},
#  'metadata': {'run_id': '78a6d2c5-4982-406b-b356-0ca213086555',
#   'feedback_tokens': []}}

# %% [markdown]
# You can also interact with this via the RemoteRunnable interface (to use in other chains)

# %%
from langserve import RemoteRunnable

remote_runnable = RemoteRunnable("http://localhost:8000/")

# %% [markdown]
# Remote runnable has the same interface as local runnables

# %%
await remote_runnable.ainvoke({"input": "hi!"})
# Out:
# {'output': 'Hello! How can I assist you today?'}

# %%
remote_runnable.invoke({"input": "what does eugene think of cats?"})
# Out:
# {'output': 'Eugene thinks that cats like fish.'}

# %% [markdown]
# ## Stream
#
# Please note that streaming alternates between actions and observations. It does not stream individual tokens! If you need to stream individual tokens you will need to use astream_log!

# %%
async for chunk in remote_runnable.astream({"input": "what does eugene think of cats? Then tell me a story about that thought."}):
    print('--')
    print(chunk)
# Out:
# --
# {'actions': [AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-0ee02e6e-d436-4a8d-9a6e-935c74a1bad8')])], 'messages': [AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-0ee02e6e-d436-4a8d-9a6e-935c74a1bad8')]}
# --
# {'steps': [{'action': AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-0ee02e6e-d436-4a8d-9a6e-935c74a1bad8')]), 'observation': [Document(page_content='cats like fish'), Document(page_content='dogs like sticks')]}], 'messages': [FunctionMessage(content="[Document(page_content='cats like fish'), Document(page_content='dogs like sticks')]", name='get_eugene_thoughts')]}
# --
# {'output': 'Eugene thinks that cats like fish. Now, let me tell you a story about Eugene\'s thoughts on cats.\n\nOnce upon a time, in a small village, there lived a mischievous cat named Whiskers. Whiskers was known for his love of fish. Every day, he would sneak into the village\'s fish market and try to snatch a fresh fish for himself.\n\nOne day, Eugene, a curious observer, noticed Whiskers\' behavior and became fascinated by the cat\'s obsession with fish. Eugene decided to follow Whiskers and see where his adventures would lead.\n\nAs Eugene followed Whiskers, he witnessed the cat\'s incredible agility and stealth. Whiskers would carefully navigate through the market stalls, avoiding the watchful eyes of the vendors. He would pounce on the perfect moment, swiftly grabbing a fish and disappearing into the shadows.\n\nEugene couldn\'t help but admire Whiskers\' determination and skill. He realized that Whiskers\' love for fish was not just about satisfying his hunger but also a reflection of his natural instincts and hunting abilities.\n\nInspired by Whiskers\' story, Eugene decided to document the adventures of the mischievous cat. He wrote a book called "Whiskers and the Fishy Tales," which became a bestseller. The book not only entertained readers but also shed light on the fascinating world of cats and their love for fish.\n\nThanks to Eugene\'s observations and Whiskers\' escapades, people began to appreciate cats even more. They understood that cats, like Whiskers, have unique traits and behaviors that make them special companions.\n\nAnd so, the story of Whiskers and Eugene\'s fascination with cats and their love for fish became a timeless tale, reminding us of the beauty and wonder of our feline friends.\n\nThe end.', 'messages': [AIMessage(content='Eugene thinks that cats like fish. Now, let me tell you a story about Eugene\'s thoughts on cats.\n\nOnce upon a time, in a small village, there lived a mischievous cat named Whiskers. Whiskers was known for his love of fish. Every day, he would sneak into the village\'s fish market and try to snatch a fresh fish for himself.\n\nOne day, Eugene, a curious observer, noticed Whiskers\' behavior and became fascinated by the cat\'s obsession with fish. Eugene decided to follow Whiskers and see where his adventures would lead.\n\nAs Eugene followed Whiskers, he witnessed the cat\'s incredible agility and stealth. Whiskers would carefully navigate through the market stalls, avoiding the watchful eyes of the vendors. He would pounce on the perfect moment, swiftly grabbing a fish and disappearing into the shadows.\n\nEugene couldn\'t help but admire Whiskers\' determination and skill. He realized that Whiskers\' love for fish was not just about satisfying his hunger but also a reflection of his natural instincts and hunting abilities.\n\nInspired by Whiskers\' story, Eugene decided to document the adventures of the mischievous cat. He wrote a book called "Whiskers and the Fishy Tales," which became a bestseller. The book not only entertained readers but also shed light on the fascinating world of cats and their love for fish.\n\nThanks to Eugene\'s observations and Whiskers\' escapades, people began to appreciate cats even more. They understood that cats, like Whiskers, have unique traits and behaviors that make them special companions.\n\nAnd so, the story of Whiskers and Eugene\'s fascination with cats and their love for fish became a timeless tale, reminding us of the beauty and wonder of our feline friends.\n\nThe end.')]}

# %% [markdown]
# ## Stream Events
#
# The client is looking for a runnable name called `agent` for the chain events. This name was defined on the server side using `runnable.with_config({"run_name": "agent"}`

# %%
async for event in remote_runnable.astream_events(
    {"input": "what does eugene think of cats? Then tell me a story about that thought."},
    version="v1",
):
    kind = event["event"]
    if kind == "on_chain_start":
        if (
            event["name"] == "agent"
        ):  # Was assigned when creating the agent with `.with_config({"run_name": "Agent"})`
            print(
                f"Starting agent: {event['name']} with input: {event['data'].get('input')}"
            )
    elif kind == "on_chain_end":
        if (
            event["name"] == "agent"
        ):  # Was assigned when creating the agent with `.with_config({"run_name": "Agent"})`
            print()
            print("--")
            print(
                f"Done agent: {event['name']} with output: {event['data'].get('output')['output']}"
            )
    if kind == "on_chat_model_stream":
        content = event["data"]["chunk"].content
        if content:
            # Empty content in the context of OpenAI means
            # that the model is asking for a tool to be invoked.
            # So we only print non-empty content
            print(content, end="|")
    elif kind == "on_tool_start":
        print("--")
        print(
            f"Starting tool: {event['name']} with inputs: {event['data'].get('input')}"
        )
    elif kind == "on_tool_end":
        print(f"Done tool: {event['name']}")
        print(f"Tool output was: {event['data'].get('output')}")
        print("--")
# Out:
# Starting agent: agent with input: {'input': 'what does eugene think of cats? Then tell me a story about that thought.'}
# --
# Starting tool: get_eugene_thoughts with inputs: {'query': 'cats'}
# Done tool: get_eugene_thoughts
# Tool output was: [Document(page_content='cats like fish'), Document(page_content='dogs like sticks')]
# --
# E|ug|ene| thinks| that| cats| like| fish|.| Now|,| let| me| tell| you| a| story| about| Eugene|'s| thoughts| on| cats|.
#
# |Once| upon| a| time|,| in| a| small| village|,| there| lived| a| mis|chie|vous| cat| named| Wh|isk|ers|.| Wh|isk|ers| was| known| for| his| love| of| fish|.| Every| day|,| he| would| sneak| into| the| village|'s| fish| market| and| try| to| snatch| a| fresh| fish| for| himself|.
#
# |One| day|,| Eugene|,| a| curious| observer|,| noticed| Wh|isk|ers|'| behavior| and| became| fascinated| by| the| cat|'s| obsession| with| fish|.| Eugene| decided| to| follow| Wh|isk|ers| and| see| where| his| adventures| would| lead|.
#
# |As| Eugene| followed| Wh|isk|ers|,| he| witnessed| the| cat|'s| incredible| agility| and| stealth|.| Wh|isk|ers| would| carefully| navigate| through| the| market| stalls|,| avoiding| the| watch|ful| eyes| of| the| vendors|.| He| would| p|ounce| on| the| perfect| moment|,| swiftly| grabbing| a| fish| and| disappearing| into| the| shadows|.
#
# |E|ug|ene| couldn|'t| help| but| admire| Wh|isk|ers|'| determination| and| skill|.| He| realized| that| Wh|isk|ers|'| love| for| fish| was| not| just| about| satisfying| his| hunger| but| also| a| reflection| of| his| natural| instincts| and| hunting| abilities|.
#
# |Insp|ired| by| Wh|isk|ers|'| story|,| Eugene| decided| to| document| the| adventures| of| the| mis|chie|vous| cat|.| He| wrote| a| book| called| "|Wh|isk|ers| and| the| Fish|y| Tales|,"| which| became| a| best|seller|.| The| book| not| only| entertained| readers| but| also| shed| light| on| the| fascinating| world| of| cats| and| their| love| for| fish|.
#
# |Thanks| to| Eugene|'s| observations| and| Wh|isk|ers|'| escap|ades|,| people| began| to| appreciate| cats| even| more|.| They| understood| that| cats|,| like| Wh|isk|ers|,| have| unique| traits| and| behaviors| that| make| them| special| companions|.
#
# |And| so|,| the| story| of| Wh|isk|ers| and| Eugene|'s| fascination| with| cats| and| their| love| for| fish| became| a| timeless| tale|,| reminding| us| of| the| beauty| and| wonder| of| our| f|eline| friends|.
#
# |The| end|.|
# --
# Done agent: agent with output: Eugene thinks that cats like fish. Now, let me tell you a story about Eugene's thoughts on cats.
#
# Once upon a time, in a small village, there lived a mischievous cat named Whiskers. Whiskers was known for his love of fish. Every day, he would sneak into the village's fish market and try to snatch a fresh fish for himself.
#
# One day, Eugene, a curious observer, noticed Whiskers' behavior and became fascinated by the cat's obsession with fish. Eugene decided to follow Whiskers and see where his adventures would lead.
#
# As Eugene followed Whiskers, he witnessed the cat's incredible agility and stealth. Whiskers would carefully navigate through the market stalls, avoiding the watchful eyes of the vendors. He would pounce on the perfect moment, swiftly grabbing a fish and disappearing into the shadows.
#
# Eugene couldn't help but admire Whiskers' determination and skill. He realized that Whiskers' love for fish was not just about satisfying his hunger but also a reflection of his natural instincts and hunting abilities.
#
# Inspired by Whiskers' story, Eugene decided to document the adventures of the mischievous cat. He wrote a book called "Whiskers and the Fishy Tales," which became a bestseller. The book not only entertained readers but also shed light on the fascinating world of cats and their love for fish.
#
# Thanks to Eugene's observations and Whiskers' escapades, people began to appreciate cats even more. They understood that cats, like Whiskers, have unique traits and behaviors that make them special companions.
#
# And so, the story of Whiskers and Eugene's fascination with cats and their love for fish became a timeless tale, reminding us of the beauty and wonder of our feline friends.
#
# The end.

# %% [markdown]
# ## Stream log
#
# If you need acccess the individual llm tokens from an agent use `astream_log`. Please make sure that you set **streaming=True** on your LLM (see server code). For this to work, the LLM must also support streaming!

# %%
async for chunk in remote_runnable.astream_log({"input": "what does eugene think of cats?"}):
    print('--')
    print(chunk)
# Out:
# --
# RunLogPatch({'op': 'replace',
#   'path': '',
#   'value': {'final_output': None,
#             'id': '24c03cd4-f49e-4bb6-96c7-8f67bc7fa13b',
#             'logs': {},
#             'name': 'agent',
#             'streamed_output': [],
#             'type': 'chain'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'fd41d343-b1a9-4f78-b4b7-a3a80f6de867',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.1',
#                          '__useragent': 'python-httpx/0.27.0'},
#             'name': 'RunnableSequence',
#             'start_time': '2024-06-15T02:37:29.905+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': [],
#             'type': 'chain'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'ed42a84e-58c0-4ec3-adb2-f04f1e4ec2c7',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.1',
#                          '__useragent': 'python-httpx/0.27.0'},
#             'name': 'RunnableParallel<input,agent_scratchpad>',
#             'start_time': '2024-06-15T02:37:29.907+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:1'],
#             'type': 'chain'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '39b428db-0a5e-4e42-97d0-e7133e0360ba',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.1',
#                          '__useragent': 'python-httpx/0.27.0'},
#             'name': 'RunnableLambda',
#             'start_time': '2024-06-15T02:37:29.909+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['map:key:input'],
#             'type': 'chain'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:2',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '4ed218bd-6dba-42f8-be98-ad7bd9bc3fc1',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.1',
#                          '__useragent': 'python-httpx/0.27.0'},
#             'name': 'RunnableLambda',
#             'start_time': '2024-06-15T02:37:29.909+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['map:key:agent_scratchpad'],
#             'type': 'chain'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda/streamed_output/-',
#   'value': 'what does eugene think of cats?'})
# --
# RunLogPatch({'op': 'add', 'path': '/logs/RunnableLambda:2/streamed_output/-', 'value': []})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>/streamed_output/-',
#   'value': {'input': 'what does eugene think of cats?'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>/streamed_output/-',
#   'value': {'agent_scratchpad': []}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda/final_output',
#   'value': {'output': 'what does eugene think of cats?'}},
#  {'op': 'add',
#   'path': '/logs/RunnableLambda/end_time',
#   'value': '2024-06-15T02:37:29.910+00:00'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:2/final_output',
#   'value': {'output': []}},
#  {'op': 'add',
#   'path': '/logs/RunnableLambda:2/end_time',
#   'value': '2024-06-15T02:37:29.910+00:00'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>/final_output',
#   'value': {'agent_scratchpad': [],
#             'input': 'what does eugene think of cats?'}},
#  {'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>/end_time',
#   'value': '2024-06-15T02:37:29.910+00:00'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatPromptTemplate',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'b12c58e9-903f-495e-803e-9c40c4c93dcd',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.1',
#                          '__useragent': 'python-httpx/0.27.0'},
#             'name': 'ChatPromptTemplate',
#             'start_time': '2024-06-15T02:37:29.911+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:2'],
#             'type': 'prompt'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatPromptTemplate/final_output',
#   'value': {'messages': [SystemMessage(content='You are a helpful assistant.'),
#                          HumanMessage(content='what does eugene think of cats?')]}},
#  {'op': 'add',
#   'path': '/logs/ChatPromptTemplate/end_time',
#   'value': '2024-06-15T02:37:29.911+00:00'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '44f64ff1-6d0c-4ed4-815e-e74d6aba1d07',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.1',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'ls_model_type': 'chat'},
#             'name': 'AzureChatOpenAI',
#             'start_time': '2024-06-15T02:37:29.912+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:3'],
#             'type': 'llm'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output_str/-',
#   'value': ''},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '', 'name': 'get_eugene_thoughts'}}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output_str/-',
#   'value': ''},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n', 'name': ''}}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output_str/-',
#   'value': ''},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': ' ', 'name': ''}}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output_str/-',
#   'value': ''},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': ' "', 'name': ''}}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output_str/-',
#   'value': ''},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': 'query', 'name': ''}}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output_str/-',
#   'value': ''},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '":', 'name': ''}}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output_str/-',
#   'value': ''},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': ' "', 'name': ''}}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output_str/-',
#   'value': ''},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': 'cats', 'name': ''}}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output_str/-',
#   'value': ''},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '"\n', 'name': ''}}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output_str/-',
#   'value': ''},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '}', 'name': ''}}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output_str/-',
#   'value': ''},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI/streamed_output/-',
#   'value': AIMessageChunk(content='', response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI/final_output',
#   'value': LLMResult(generations=[[ChatGenerationChunk(generation_info={'finish_reason': 'function_call'}, message=AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07'))]], llm_output=None, run=None)},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI/end_time',
#   'value': '2024-06-15T02:37:33.547+00:00'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/OpenAIFunctionsAgentOutputParser',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'd6fe5fad-1636-4653-bfc8-908ce27d6a10',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.1',
#                          '__useragent': 'python-httpx/0.27.0'},
#             'name': 'OpenAIFunctionsAgentOutputParser',
#             'start_time': '2024-06-15T02:37:33.548+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:4'],
#             'type': 'parser'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/OpenAIFunctionsAgentOutputParser/final_output',
#   'value': {'output': AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')])}},
#  {'op': 'add',
#   'path': '/logs/OpenAIFunctionsAgentOutputParser/end_time',
#   'value': '2024-06-15T02:37:33.548+00:00'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence/streamed_output/-',
#   'value': AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')])})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence/final_output',
#   'value': {'output': AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')])}},
#  {'op': 'add',
#   'path': '/logs/RunnableSequence/end_time',
#   'value': '2024-06-15T02:37:33.549+00:00'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': {'actions': [AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')])],
#             'messages': [AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')]}},
#  {'op': 'replace',
#   'path': '/final_output',
#   'value': {'actions': [AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')])],
#             'messages': [AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')]}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/get_eugene_thoughts',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '984ace46-61a2-4daa-a0eb-07cc96953caa',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.1',
#                          '__useragent': 'python-httpx/0.27.0'},
#             'name': 'get_eugene_thoughts',
#             'start_time': '2024-06-15T02:37:33.550+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': [],
#             'type': 'tool'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/get_eugene_thoughts/final_output',
#   'value': {'output': [Document(page_content='cats like fish'),
#                        Document(page_content='dogs like sticks')]}},
#  {'op': 'add',
#   'path': '/logs/get_eugene_thoughts/end_time',
#   'value': '2024-06-15T02:37:33.911+00:00'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': {'messages': [FunctionMessage(content="[Document(page_content='cats like fish'), Document(page_content='dogs like sticks')]", name='get_eugene_thoughts')],
#             'steps': [{'action': AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')]),
#                        'observation': [Document(page_content='cats like fish'),
#                                        Document(page_content='dogs like sticks')]}]}},
#  {'op': 'add',
#   'path': '/final_output/steps',
#   'value': [{'action': AgentActionMessageLog(tool='get_eugene_thoughts', tool_input={'query': 'cats'}, log="\nInvoking: `get_eugene_thoughts` with `{'query': 'cats'}`\n\n\n", message_log=[AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07')]),
#              'observation': [Document(page_content='cats like fish'),
#                              Document(page_content='dogs like sticks')]}]},
#  {'op': 'add',
#   'path': '/final_output/messages/1',
#   'value': FunctionMessage(content="[Document(page_content='cats like fish'), Document(page_content='dogs like sticks')]", name='get_eugene_thoughts')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence:2',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'a2ca5e8e-7bb3-40ee-a7db-e2c036a4ed68',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.1',
#                          '__useragent': 'python-httpx/0.27.0'},
#             'name': 'RunnableSequence',
#             'start_time': '2024-06-15T02:37:33.914+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': [],
#             'type': 'chain'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>:2',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'f9f91d27-fb5a-465d-8171-b7bbf6e1ce33',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.1',
#                          '__useragent': 'python-httpx/0.27.0'},
#             'name': 'RunnableParallel<input,agent_scratchpad>',
#             'start_time': '2024-06-15T02:37:33.917+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:1'],
#             'type': 'chain'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:3',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'bda7cd5e-4926-4de3-8497-729521eec328',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.1',
#                          '__useragent': 'python-httpx/0.27.0'},
#             'name': 'RunnableLambda',
#             'start_time': '2024-06-15T02:37:33.917+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['map:key:input'],
#             'type': 'chain'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:4',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '8daceb78-f4c4-425f-8e67-dbb1edc0ceb1',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.1',
#                          '__useragent': 'python-httpx/0.27.0'},
#             'name': 'RunnableLambda',
#             'start_time': '2024-06-15T02:37:33.917+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['map:key:agent_scratchpad'],
#             'type': 'chain'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:3/streamed_output/-',
#   'value': 'what does eugene think of cats?'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:4/streamed_output/-',
#   'value': [AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07'),
#             FunctionMessage(content="[Document(page_content='cats like fish'), Document(page_content='dogs like sticks')]", name='get_eugene_thoughts')]})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>:2/streamed_output/-',
#   'value': {'input': 'what does eugene think of cats?'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>:2/streamed_output/-',
#   'value': {'agent_scratchpad': [AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07'),
#                                  FunctionMessage(content="[Document(page_content='cats like fish'), Document(page_content='dogs like sticks')]", name='get_eugene_thoughts')]}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:3/final_output',
#   'value': {'output': 'what does eugene think of cats?'}},
#  {'op': 'add',
#   'path': '/logs/RunnableLambda:3/end_time',
#   'value': '2024-06-15T02:37:33.918+00:00'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableLambda:4/final_output',
#   'value': {'output': [AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07'),
#                        FunctionMessage(content="[Document(page_content='cats like fish'), Document(page_content='dogs like sticks')]", name='get_eugene_thoughts')]}},
#  {'op': 'add',
#   'path': '/logs/RunnableLambda:4/end_time',
#   'value': '2024-06-15T02:37:33.919+00:00'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>:2/final_output',
#   'value': {'agent_scratchpad': [AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07'),
#                                  FunctionMessage(content="[Document(page_content='cats like fish'), Document(page_content='dogs like sticks')]", name='get_eugene_thoughts')],
#             'input': 'what does eugene think of cats?'}},
#  {'op': 'add',
#   'path': '/logs/RunnableParallel<input,agent_scratchpad>:2/end_time',
#   'value': '2024-06-15T02:37:33.919+00:00'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatPromptTemplate:2',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '8ca93de6-9961-4639-8999-100f4a5a33af',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.1',
#                          '__useragent': 'python-httpx/0.27.0'},
#             'name': 'ChatPromptTemplate',
#             'start_time': '2024-06-15T02:37:33.920+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:2'],
#             'type': 'prompt'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/ChatPromptTemplate:2/final_output',
#   'value': {'messages': [SystemMessage(content='You are a helpful assistant.'),
#                          HumanMessage(content='what does eugene think of cats?'),
#                          AIMessageChunk(content='', additional_kwargs={'function_call': {'arguments': '{\n  "query": "cats"\n}', 'name': 'get_eugene_thoughts'}}, response_metadata={'finish_reason': 'function_call'}, id='run-44f64ff1-6d0c-4ed4-815e-e74d6aba1d07'),
#                          FunctionMessage(content="[Document(page_content='cats like fish'), Document(page_content='dogs like sticks')]", name='get_eugene_thoughts')]}},
#  {'op': 'add',
#   'path': '/logs/ChatPromptTemplate:2/end_time',
#   'value': '2024-06-15T02:37:33.920+00:00'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': '7d8d26d2-2500-4ed5-aee5-3525d8c21d48',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.1',
#                          '__useragent': 'python-httpx/0.27.0',
#                          'ls_model_type': 'chat'},
#             'name': 'AzureChatOpenAI',
#             'start_time': '2024-06-15T02:37:33.921+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:3'],
#             'type': 'llm'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output_str/-',
#   'value': ''},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='', id='run-7d8d26d2-2500-4ed5-aee5-3525d8c21d48')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output_str/-',
#   'value': 'E'},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='E', id='run-7d8d26d2-2500-4ed5-aee5-3525d8c21d48')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output_str/-',
#   'value': 'ug'},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='ug', id='run-7d8d26d2-2500-4ed5-aee5-3525d8c21d48')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output_str/-',
#   'value': 'ene'},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='ene', id='run-7d8d26d2-2500-4ed5-aee5-3525d8c21d48')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output_str/-',
#   'value': ' thinks'},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' thinks', id='run-7d8d26d2-2500-4ed5-aee5-3525d8c21d48')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output_str/-',
#   'value': ' that'},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' that', id='run-7d8d26d2-2500-4ed5-aee5-3525d8c21d48')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output_str/-',
#   'value': ' cats'},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' cats', id='run-7d8d26d2-2500-4ed5-aee5-3525d8c21d48')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output_str/-',
#   'value': ' like'},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' like', id='run-7d8d26d2-2500-4ed5-aee5-3525d8c21d48')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output_str/-',
#   'value': ' fish'},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content=' fish', id='run-7d8d26d2-2500-4ed5-aee5-3525d8c21d48')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output_str/-',
#   'value': '.'},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='.', id='run-7d8d26d2-2500-4ed5-aee5-3525d8c21d48')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output_str/-',
#   'value': ''},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/streamed_output/-',
#   'value': AIMessageChunk(content='', response_metadata={'finish_reason': 'stop'}, id='run-7d8d26d2-2500-4ed5-aee5-3525d8c21d48')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/final_output',
#   'value': LLMResult(generations=[[ChatGenerationChunk(text='Eugene thinks that cats like fish.', generation_info={'finish_reason': 'stop'}, message=AIMessageChunk(content='Eugene thinks that cats like fish.', response_metadata={'finish_reason': 'stop'}, id='run-7d8d26d2-2500-4ed5-aee5-3525d8c21d48'))]], llm_output=None, run=None)},
#  {'op': 'add',
#   'path': '/logs/AzureChatOpenAI:2/end_time',
#   'value': '2024-06-15T02:37:35.617+00:00'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/OpenAIFunctionsAgentOutputParser:2',
#   'value': {'end_time': None,
#             'final_output': None,
#             'id': 'e729211c-cffb-4b64-9601-c94bf50b4a1a',
#             'metadata': {'__langserve_endpoint': 'stream_log',
#                          '__langserve_version': '0.2.1',
#                          '__useragent': 'python-httpx/0.27.0'},
#             'name': 'OpenAIFunctionsAgentOutputParser',
#             'start_time': '2024-06-15T02:37:35.618+00:00',
#             'streamed_output': [],
#             'streamed_output_str': [],
#             'tags': ['seq:step:4'],
#             'type': 'parser'}})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/OpenAIFunctionsAgentOutputParser:2/final_output',
#   'value': {'output': AgentFinish(return_values={'output': 'Eugene thinks that cats like fish.'}, log='Eugene thinks that cats like fish.')}},
#  {'op': 'add',
#   'path': '/logs/OpenAIFunctionsAgentOutputParser:2/end_time',
#   'value': '2024-06-15T02:37:35.619+00:00'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence:2/streamed_output/-',
#   'value': AgentFinish(return_values={'output': 'Eugene thinks that cats like fish.'}, log='Eugene thinks that cats like fish.')})
# --
# RunLogPatch({'op': 'add',
#   'path': '/logs/RunnableSequence:2/final_output',
#   'value': {'output': AgentFinish(return_values={'output': 'Eugene thinks that cats like fish.'}, log='Eugene thinks that cats like fish.')}},
#  {'op': 'add',
#   'path': '/logs/RunnableSequence:2/end_time',
#   'value': '2024-06-15T02:37:35.619+00:00'})
# --
# RunLogPatch({'op': 'add',
#   'path': '/streamed_output/-',
#   'value': {'messages': [AIMessage(content='Eugene thinks that cats like fish.')],
#             'output': 'Eugene thinks that cats like fish.'}},
#  {'op': 'add',
#   'path': '/final_output/output',
#   'value': 'Eugene thinks that cats like fish.'},
#  {'op': 'add',
#   'path': '/final_output/messages/2',
#   'value': AIMessage(content='Eugene thinks that cats like fish.')})
